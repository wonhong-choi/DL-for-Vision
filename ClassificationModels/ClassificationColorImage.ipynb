# %%
import keras
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt


def data_load():
    (X_train, y_train), (X_test, y_test) = cifar10.load_data()
    return X_train, y_train, X_test, y_test

def data_preview(X_train):
    fig = plt.figure(figsize=(20,5))
    for i in range(36):
        ax=fig.add_subplot(3, 12, i+1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(X_train[i]))

def normalize(X_train, X_test):
    X_train = X_train.astype('float32')/255
    X_test = X_test.astype('float32')/255
    return X_train, X_test

def one_hot(y_train, y_test):
    num_classes=len(np.unique(y_train))
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    return y_train, y_test

def split(X_train, y_train, valid_nums=5000):
    X_train, X_valid = X_train[valid_nums:], X_train[:valid_nums]
    y_train, y_valid = y_train[valid_nums:], y_train[:valid_nums]
    return X_train, X_valid, y_train, y_valid
    
def mini_AlexNet():
    cnn = Sequential()
    cnn.add(Conv2D(filters=16, kernel_size=2, padding='same',\
        activation='relu', input_shape = (32, 32, 3)))
    cnn.add(MaxPooling2D(pool_size=2))
    cnn.add(Conv2D(filters=32, kernel_size=2, padding='same',\
        activation='relu', input_shape = (32, 32, 3)))
    cnn.add(MaxPooling2D(pool_size=2))
    cnn.add(Conv2D(filters=64, kernel_size=2, padding='same',\
        activation='relu', input_shape = (32, 32, 3)))
    cnn.add(MaxPooling2D(pool_size=2))
    
    cnn.add(Dropout(rate=0.3))

    cnn.add(Flatten())

    cnn.add(Dense(500, activation='relu'))
    cnn.add(Dropout(rate=0.4))

    cnn.add(Dense(10, activation='softmax'))
    return cnn

# %%
X_train, y_train, X_test, y_test=data_load()

X_train, X_test = normalize(X_train, X_test)

y_train, y_test = one_hot(y_train, y_test)

X_train, X_valid, y_train, y_valid = split(X_train, y_train)

model=mini_AlexNet()
model.compile(loss='categorical_crossentropy', optimizer='rmsprop',\
    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)

hist= model.fit(X_train, y_train, batch_size=32, epochs=100,\
    validation_data=(X_valid, y_valid), callbacks=[checkpointer],\
        verbose=2, shuffle=True)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.42570, saving model to model.weights.best.hdf5
# 1407/1407 - 19s - loss: 1.6390 - accuracy: 0.4008 - val_loss: 1.4257 - val_accuracy: 0.4784 - 19s/epoch - 13ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.42570 to 1.39785, saving model to model.weights.best.hdf5
# 1407/1407 - 19s - loss: 1.3213 - accuracy: 0.5282 - val_loss: 1.3978 - val_accuracy: 0.5134 - 19s/epoch - 13ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.39785 to 1.14783, saving model to model.weights.best.hdf5
# 1407/1407 - 17s - loss: 1.1862 - accuracy: 0.5786 - val_loss: 1.1478 - val_accuracy: 0.5912 - 17s/epoch - 12ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.14783 to 1.06704, saving model to model.weights.best.hdf5
# 1407/1407 - 17s - loss: 1.1082 - accuracy: 0.6093 - val_loss: 1.0670 - val_accuracy: 0.6276 - 17s/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.06704 to 1.02083, saving model to model.weights.best.hdf5
# 1407/1407 - 15s - loss: 1.0576 - accuracy: 0.6272 - val_loss: 1.0208 - val_accuracy: 0.6500 - 15s/epoch - 11ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.02083 to 1.01349, saving model to model.weights.best.hdf5
# 1407/1407 - 15s - loss: 1.0168 - accuracy: 0.6449 - val_loss: 1.0135 - val_accuracy: 0.6478 - 15s/epoch - 11ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.01349 to 0.93957, saving model to model.weights.best.hdf5
# 1407/1407 - 16s - loss: 0.9801 - accuracy: 0.6589 - val_loss: 0.9396 - val_accuracy: 0.6762 - 16s/epoch - 11ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.93957 to 0.92709, saving model to model.weights.best.hdf5
# 1407/1407 - 16s - loss: 0.9658 - accuracy: 0.6656 - val_loss: 0.9271 - val_accuracy: 0.6830 - 16s/epoch - 11ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.92709 to 0.89080, saving model to model.weights.best.hdf5
# 1407/1407 - 15s - loss: 0.9478 - accuracy: 0.6749 - val_loss: 0.8908 - val_accuracy: 0.7014 - 15s/epoch - 11ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.89080 to 0.88736, saving model to model.weights.best.hdf5
# 1407/1407 - 15s - loss: 0.9371 - accuracy: 0.6789 - val_loss: 0.8874 - val_accuracy: 0.7008 - 15s/epoch - 11ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.88736
# 1407/1407 - 15s - loss: 0.9266 - accuracy: 0.6818 - val_loss: 0.9174 - val_accuracy: 0.6922 - 15s/epoch - 11ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.88736
# 1407/1407 - 19s - loss: 0.9188 - accuracy: 0.6858 - val_loss: 0.9102 - val_accuracy: 0.6982 - 19s/epoch - 13ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.88736
# 1407/1407 - 15s - loss: 0.9175 - accuracy: 0.6883 - val_loss: 0.9668 - val_accuracy: 0.6878 - 15s/epoch - 11ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.88736
# 1407/1407 - 16s - loss: 0.9079 - accuracy: 0.6907 - val_loss: 0.9006 - val_accuracy: 0.6952 - 16s/epoch - 11ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.88736
# 1407/1407 - 19s - loss: 0.9121 - accuracy: 0.6920 - val_loss: 0.9700 - val_accuracy: 0.6786 - 19s/epoch - 13ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.88736
# 1407/1407 - 19s - loss: 0.9039 - accuracy: 0.6968 - val_loss: 0.9623 - val_accuracy: 0.6794 - 19s/epoch - 14ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.88736
# 1407/1407 - 15s - loss: 0.9070 - accuracy: 0.6938 - val_loss: 0.9746 - val_accuracy: 0.6904 - 15s/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.88736
# 1407/1407 - 16s - loss: 0.9084 - accuracy: 0.6974 - val_loss: 0.9902 - val_accuracy: 0.6668 - 16s/epoch - 11ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.88736
# 1407/1407 - 15s - loss: 0.9035 - accuracy: 0.6982 - val_loss: 0.8902 - val_accuracy: 0.7110 - 15s/epoch - 11ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.88736
# 1407/1407 - 18s - loss: 0.9172 - accuracy: 0.6929 - val_loss: 0.9991 - val_accuracy: 0.6696 - 18s/epoch - 13ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.88736 to 0.86228, saving model to model.weights.best.hdf5
# 1407/1407 - 18s - loss: 0.9215 - accuracy: 0.6960 - val_loss: 0.8623 - val_accuracy: 0.7180 - 18s/epoch - 13ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 0.9272 - accuracy: 0.6929 - val_loss: 0.8847 - val_accuracy: 0.6968 - 15s/epoch - 11ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 0.9355 - accuracy: 0.6908 - val_loss: 0.9793 - val_accuracy: 0.6878 - 15s/epoch - 11ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 0.9575 - accuracy: 0.6879 - val_loss: 1.0110 - val_accuracy: 0.6978 - 16s/epoch - 11ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 0.9656 - accuracy: 0.6839 - val_loss: 1.3608 - val_accuracy: 0.5926 - 15s/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 0.9788 - accuracy: 0.6813 - val_loss: 0.9134 - val_accuracy: 0.7016 - 15s/epoch - 11ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 0.9818 - accuracy: 0.6824 - val_loss: 1.2301 - val_accuracy: 0.6318 - 15s/epoch - 11ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 0.9945 - accuracy: 0.6757 - val_loss: 0.9789 - val_accuracy: 0.6930 - 19s/epoch - 13ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.0156 - accuracy: 0.6691 - val_loss: 0.9698 - val_accuracy: 0.6846 - 15s/epoch - 11ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.0281 - accuracy: 0.6657 - val_loss: 1.3082 - val_accuracy: 0.5856 - 16s/epoch - 11ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.0478 - accuracy: 0.6609 - val_loss: 0.9675 - val_accuracy: 0.6940 - 17s/epoch - 12ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.0691 - accuracy: 0.6552 - val_loss: 1.1720 - val_accuracy: 0.6396 - 19s/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.0921 - accuracy: 0.6492 - val_loss: 1.3397 - val_accuracy: 0.6190 - 15s/epoch - 11ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.1186 - accuracy: 0.6397 - val_loss: 1.1762 - val_accuracy: 0.6264 - 16s/epoch - 11ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.1432 - accuracy: 0.6322 - val_loss: 1.1651 - val_accuracy: 0.6208 - 16s/epoch - 11ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.1620 - accuracy: 0.6274 - val_loss: 1.0005 - val_accuracy: 0.6714 - 17s/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.1770 - accuracy: 0.6227 - val_loss: 1.2247 - val_accuracy: 0.6134 - 17s/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.2104 - accuracy: 0.6137 - val_loss: 1.6309 - val_accuracy: 0.5760 - 17s/epoch - 12ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.2233 - accuracy: 0.6059 - val_loss: 1.1876 - val_accuracy: 0.6140 - 16s/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.2360 - accuracy: 0.6010 - val_loss: 1.2323 - val_accuracy: 0.5948 - 15s/epoch - 11ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.2575 - accuracy: 0.5942 - val_loss: 2.1537 - val_accuracy: 0.5586 - 17s/epoch - 12ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.2496 - accuracy: 0.5987 - val_loss: 1.1122 - val_accuracy: 0.6428 - 19s/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.2631 - accuracy: 0.5950 - val_loss: 1.8162 - val_accuracy: 0.5786 - 16s/epoch - 11ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.2830 - accuracy: 0.5873 - val_loss: 1.4548 - val_accuracy: 0.6028 - 15s/epoch - 11ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.2822 - accuracy: 0.5883 - val_loss: 1.0797 - val_accuracy: 0.6534 - 18s/epoch - 13ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.2915 - accuracy: 0.5814 - val_loss: 1.0543 - val_accuracy: 0.6560 - 18s/epoch - 13ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.3017 - accuracy: 0.5801 - val_loss: 1.3518 - val_accuracy: 0.5644 - 18s/epoch - 13ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.2922 - accuracy: 0.5856 - val_loss: 1.3367 - val_accuracy: 0.6344 - 16s/epoch - 11ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3043 - accuracy: 0.5800 - val_loss: 1.1222 - val_accuracy: 0.6310 - 16s/epoch - 11ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.3010 - accuracy: 0.5784 - val_loss: 1.7757 - val_accuracy: 0.5846 - 17s/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.3097 - accuracy: 0.5766 - val_loss: 1.6549 - val_accuracy: 0.3958 - 17s/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.86228
# 1407/1407 - 20s - loss: 1.3163 - accuracy: 0.5742 - val_loss: 1.4937 - val_accuracy: 0.5310 - 20s/epoch - 14ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.86228
# 1407/1407 - 22s - loss: 1.2959 - accuracy: 0.5773 - val_loss: 1.2445 - val_accuracy: 0.5742 - 22s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.3159 - accuracy: 0.5799 - val_loss: 1.2493 - val_accuracy: 0.5690 - 19s/epoch - 14ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3039 - accuracy: 0.5756 - val_loss: 1.1234 - val_accuracy: 0.6536 - 16s/epoch - 11ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3150 - accuracy: 0.5749 - val_loss: 1.8977 - val_accuracy: 0.5048 - 16s/epoch - 11ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.3300 - accuracy: 0.5688 - val_loss: 1.4848 - val_accuracy: 0.5784 - 17s/epoch - 12ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.3379 - accuracy: 0.5681 - val_loss: 1.3029 - val_accuracy: 0.5932 - 15s/epoch - 11ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.3435 - accuracy: 0.5710 - val_loss: 1.3648 - val_accuracy: 0.5558 - 15s/epoch - 11ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.3522 - accuracy: 0.5597 - val_loss: 1.3372 - val_accuracy: 0.5458 - 19s/epoch - 14ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3492 - accuracy: 0.5610 - val_loss: 1.3181 - val_accuracy: 0.5924 - 16s/epoch - 11ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3846 - accuracy: 0.5533 - val_loss: 1.3214 - val_accuracy: 0.5354 - 16s/epoch - 11ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3838 - accuracy: 0.5493 - val_loss: 1.4470 - val_accuracy: 0.5042 - 16s/epoch - 11ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3995 - accuracy: 0.5407 - val_loss: 1.1881 - val_accuracy: 0.5996 - 16s/epoch - 11ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.3976 - accuracy: 0.5462 - val_loss: 1.2876 - val_accuracy: 0.5468 - 16s/epoch - 11ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.4096 - accuracy: 0.5387 - val_loss: 1.6975 - val_accuracy: 0.5038 - 19s/epoch - 14ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4228 - accuracy: 0.5386 - val_loss: 2.0002 - val_accuracy: 0.5412 - 16s/epoch - 11ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4316 - accuracy: 0.5335 - val_loss: 1.4382 - val_accuracy: 0.5410 - 16s/epoch - 11ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4377 - accuracy: 0.5373 - val_loss: 2.7319 - val_accuracy: 0.4818 - 16s/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.4448 - accuracy: 0.5248 - val_loss: 1.4602 - val_accuracy: 0.5110 - 17s/epoch - 12ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4545 - accuracy: 0.5282 - val_loss: 1.3919 - val_accuracy: 0.5486 - 16s/epoch - 11ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.4519 - accuracy: 0.5295 - val_loss: 1.1755 - val_accuracy: 0.6056 - 17s/epoch - 12ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.86228
# 1407/1407 - 20s - loss: 1.4443 - accuracy: 0.5265 - val_loss: 1.4081 - val_accuracy: 0.5410 - 20s/epoch - 15ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.4471 - accuracy: 0.5255 - val_loss: 1.4221 - val_accuracy: 0.5772 - 17s/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4694 - accuracy: 0.5188 - val_loss: 1.2419 - val_accuracy: 0.5734 - 16s/epoch - 11ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4844 - accuracy: 0.5136 - val_loss: 2.0209 - val_accuracy: 0.4778 - 16s/epoch - 11ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.4824 - accuracy: 0.5124 - val_loss: 2.2534 - val_accuracy: 0.3022 - 19s/epoch - 14ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.4910 - accuracy: 0.5122 - val_loss: 1.9667 - val_accuracy: 0.5740 - 16s/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.86228
# 1407/1407 - 20s - loss: 1.5002 - accuracy: 0.5061 - val_loss: 1.3455 - val_accuracy: 0.5458 - 20s/epoch - 14ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.4919 - accuracy: 0.5111 - val_loss: 1.4637 - val_accuracy: 0.5026 - 19s/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.5152 - accuracy: 0.5044 - val_loss: 1.4713 - val_accuracy: 0.5060 - 15s/epoch - 11ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.5100 - accuracy: 0.5009 - val_loss: 1.4414 - val_accuracy: 0.4742 - 15s/epoch - 11ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.5292 - accuracy: 0.4947 - val_loss: 1.2971 - val_accuracy: 0.5380 - 17s/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.5534 - accuracy: 0.4906 - val_loss: 1.3699 - val_accuracy: 0.5340 - 17s/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.5533 - accuracy: 0.4878 - val_loss: 1.2909 - val_accuracy: 0.5668 - 18s/epoch - 13ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.5645 - accuracy: 0.4828 - val_loss: 1.4739 - val_accuracy: 0.5404 - 19s/epoch - 13ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.5617 - accuracy: 0.4844 - val_loss: 1.6512 - val_accuracy: 0.5222 - 18s/epoch - 13ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.5832 - accuracy: 0.4818 - val_loss: 1.3705 - val_accuracy: 0.5394 - 15s/epoch - 11ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.5956 - accuracy: 0.4701 - val_loss: 2.1429 - val_accuracy: 0.4050 - 18s/epoch - 13ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.6128 - accuracy: 0.4605 - val_loss: 1.6302 - val_accuracy: 0.4180 - 18s/epoch - 13ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.6099 - accuracy: 0.4629 - val_loss: 1.4366 - val_accuracy: 0.4950 - 15s/epoch - 11ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.5942 - accuracy: 0.4671 - val_loss: 2.0771 - val_accuracy: 0.3866 - 18s/epoch - 13ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.6030 - accuracy: 0.4630 - val_loss: 1.5288 - val_accuracy: 0.4358 - 18s/epoch - 13ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.86228
# 1407/1407 - 17s - loss: 1.6197 - accuracy: 0.4580 - val_loss: 1.8069 - val_accuracy: 0.3460 - 17s/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.6230 - accuracy: 0.4584 - val_loss: 1.3757 - val_accuracy: 0.5242 - 15s/epoch - 11ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.86228
# 1407/1407 - 16s - loss: 1.6114 - accuracy: 0.4567 - val_loss: 1.2980 - val_accuracy: 0.5594 - 16s/epoch - 11ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.86228
# 1407/1407 - 21s - loss: 1.6316 - accuracy: 0.4522 - val_loss: 1.5844 - val_accuracy: 0.5340 - 21s/epoch - 15ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.86228
# 1407/1407 - 15s - loss: 1.6313 - accuracy: 0.4521 - val_loss: 1.6065 - val_accuracy: 0.4506 - 15s/epoch - 11ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.86228
# 1407/1407 - 18s - loss: 1.6444 - accuracy: 0.4526 - val_loss: 1.4490 - val_accuracy: 0.5192 - 18s/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.86228
# 1407/1407 - 19s - loss: 1.6356 - accuracy: 0.4529 - val_loss: 1.4521 - val_accuracy: 0.5134 - 19s/epoch - 13ms/step

# %%
model.load_weights('model.weights.best.hdf5')

score = model.evaluate(X_test, y_test, verbose=0)
print('\n', "Test Accuracy:", score[1])
# Out:
#  Test Accuracy: 0.7070000171661377
